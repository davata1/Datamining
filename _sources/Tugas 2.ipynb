# %% [markdown]
# # Tugas 2

# %%
import pandas as pd
data =  pd.read_csv('/content/Iris.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# show first 15 rows
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# CONSTAN SERIES

SEPAL_LENGTH_SERIES = data["SepalLengthCm"]
SEPAL_WIDTH_SERIES = data["SepalWidthCm"]
PETAL_LENGTH_SERIES = data["PetalLengthCm"]
PETAL_WIDTH_SERIES = data["PetalWidthCm"]

# %% [markdown]
# > Sepal Lenght
#   *   Equal lenght Intervals panjang kelopak bunga Iris
#   *   Dikelempokkan menjadi 3 bagian
#   *   Kecil
#   *   Sedang
#   *   Besar

# %% [markdown]
# > Sepal Widht
#   *   Equal Width Intervals panjang kelopak bunga Iris
#   *   Dikelempokkan menjadi 3 bagian
#   *   Kecil
#   *   Sedang
#   *   Besar

# %% [markdown]
# > Petal Lenght
#   *   Equal Lenght Intervals panjang mahkota bunga Iris
#   *   Dikelempokkan menjadi 3 bagian
#   *   Kecil
#   *   Sedang
#   *   Besar

# %% [markdown]
# > Petal Widht
#   *   Equal Width Intervals panjang mahkota bunga Iris
#   *   Dikelempokkan menjadi 3 bagian
#   *   Kecil
#   *   Sedang
#   *   Besar
